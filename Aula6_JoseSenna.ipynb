# %% [markdown]
# PLOTAGEM DE EQUAÇÕES

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.linspace(-10,10,num=10)
x2 = np.linspace(-10,10,num=10)

plt.title("Equações")
plt.plot(2*x1+x2-3)
plt.plot(x1-3*x2+2)
plt.show()
